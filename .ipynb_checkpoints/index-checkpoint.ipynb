# %%
import pandas as pd
import sqlite3 
conn = sqlite3.connect('/Users/sandylee/git/flatiron_school_mod_2_project/database.sqlite')
cur = conn.cursor()

# %%
all_german_2011_season = cur.execute("""SELECT Matches.Match_ID, HomeTeam, AwayTeam, FTHG, FTAG, FTR
                       From Matches
                       JOIN Teams_in_Matches
                       ON Matches.Match_ID = Teams_in_Matches.Match_ID
                       WHERE Matches.Season = 2011 AND (Matches.Div = "D1" OR Matches.Div = "D2")
                       """)

# %%
all_german_2011_season_df = pd.DataFrame(cur.fetchall())
all_german_2011_season_df.columns = [i[0] for i in cur.description]

# %%
all_german_2011_season_df
# Out:
#       Match_ID        HomeTeam            AwayTeam  FTHG  FTAG FTR
# 0         1092        Nurnberg       Bayern Munich     0     1   A
# 1         1092        Nurnberg       Bayern Munich     0     1   A
# 2         1093       Stuttgart       Bayern Munich     1     2   A
# 3         1093       Stuttgart       Bayern Munich     1     2   A
# 4         1094       Wolfsburg       Bayern Munich     0     1   A
# ...        ...             ...                 ...   ...   ...  ..
# 1219      1701   Ein Frankfurt  Fortuna Dusseldorf     1     1   D
# 1220      1702          Aachen  Fortuna Dusseldorf     0     0   D
# 1221      1702          Aachen  Fortuna Dusseldorf     0     0   D
# 1222      1703  Erzgebirge Aue  Fortuna Dusseldorf     2     4   A
# 1223      1703  Erzgebirge Aue  Fortuna Dusseldorf     2     4   A
#
# [1224 rows x 6 columns]

# %%
all_german_2011_season_df.to_csv(r'/Users/sandylee/Desktop/csv.csv')

# %%
away_team_goals = cur.execute("""SELECT AwayTeam AS Team, SUM(FTAG) AS TotalAwayGoals
                             From Matches
                             JOIN Teams_in_Matches
                             ON Matches.Match_ID = Teams_in_Matches.Match_ID
                             WHERE Matches.Season = 2011 AND (Matches.Div = "D1" OR Matches.Div = "D2") AND FTR = "A"
                             GROUP BY Team
                             ORDER BY Team""")

# %%
away_team_goals_df = pd.DataFrame(cur.fetchall())
away_team_goals_df.columns = [i[0] for i in cur.description]

# %%
away_team_goals_df
# Out:
#                   Team  TotalAwayGoals
# 0               Aachen               8
# 1             Augsburg               6
# 2        Bayern Munich              46
# 3               Bochum              20
# 4         Braunschweig              18
# 5              Cottbus              12
# 6             Dortmund              66
# 7              Dresden              18
# 8             Duisburg               8
# 9        Ein Frankfurt              60
# 10      Erzgebirge Aue              12
# 11             FC Koln              18
# 12  Fortuna Dusseldorf              38
# 13       Frankfurt FSV              28
# 14            Freiburg              18
# 15      Greuther Furth              34
# 16             Hamburg              16
# 17            Hannover               6
# 18       Hansa Rostock               4
# 19              Hertha              16
# 20          Hoffenheim              28
# 21          Ingolstadt               6
# 22      Kaiserslautern               8
# 23           Karlsruhe               4
# 24          Leverkusen              30
# 25          M'gladbach              34
# 26               Mainz              10
# 27         Munich 1860              32
# 28            Nurnberg              24
# 29           Paderborn              38
# 30          Schalke 04              40
# 31            St Pauli              28
# 32           Stuttgart              26
# 33        Union Berlin              20
# 34       Werder Bremen              16
# 35           Wolfsburg              20

# %%
home_team_goals = cur.execute("""SELECT HomeTeam AS Team, SUM(FTHG) AS TotalHomeGoals
                             From Matches
                             JOIN Teams_in_Matches
                             ON Matches.Match_ID = Teams_in_Matches.Match_ID
                             WHERE Matches.Season = 2011 AND (Matches.Div = "D1" OR Matches.Div = "D2") AND FTR = "H"
                             GROUP BY Team
                             ORDER BY Team""")

# %%
home_team_goals_df = pd.DataFrame(cur.fetchall())
home_team_goals_df.columns = [i[0] for i in cur.description]

# %%
home_team_goals_df
# Out:
#                   Team  TotalHomeGoals
# 0               Aachen              16
# 1             Augsburg              22
# 2        Bayern Munich              98
# 3               Bochum              36
# 4         Braunschweig              34
# 5              Cottbus              16
# 6             Dortmund              76
# 7              Dresden              42
# 8             Duisburg              40
# 9        Ein Frankfurt              70
# 10      Erzgebirge Aue              20
# 11             FC Koln              24
# 12  Fortuna Dusseldorf              58
# 13       Frankfurt FSV              14
# 14            Freiburg              26
# 15      Greuther Furth              84
# 16             Hamburg              10
# 17            Hannover              48
# 18       Hansa Rostock              16
# 19              Hertha              16
# 20          Hoffenheim              18
# 21          Ingolstadt              30
# 22      Kaiserslautern               8
# 23           Karlsruhe              34
# 24          Leverkusen              38
# 25          M'gladbach              46
# 26               Mainz              42
# 27         Munich 1860              56
# 28            Nurnberg              22
# 29           Paderborn              42
# 30          Schalke 04              88
# 31            St Pauli              62
# 32           Stuttgart              62
# 33        Union Berlin              58
# 34       Werder Bremen              46
# 35           Wolfsburg              44

# %%
#figure out what to do with results that draw

# %%
away_team_draw_goals = cur.execute("""SELECT AwayTeam AS Team, SUM(FTAG) AS TotalAwayTeamDrawGoals
                             From Matches
                             JOIN Teams_in_Matches
                             ON Matches.Match_ID = Teams_in_Matches.Match_ID
                             WHERE Matches.Season = 2011 AND (Matches.Div = "D1" OR Matches.Div = "D2") AND FTR = "D"
                             GROUP BY Team
                             ORDER BY Team""")

# %%
away_team_draw_goals_df = pd.DataFrame(cur.fetchall())
away_team_draw_goals_df.columns = [i[0] for i in cur.description]

# %%
away_team_draw_goals_df
# Out:
#                   Team  TotalAwayTeamDrawGoals
# 0               Aachen                      12
# 1             Augsburg                      18
# 2        Bayern Munich                       2
# 3               Bochum                       2
# 4         Braunschweig                      12
# 5              Cottbus                       2
# 6             Dortmund                       4
# 7              Dresden                      12
# 8             Duisburg                      14
# 9        Ein Frankfurt                      10
# 10      Erzgebirge Aue                       6
# 11             FC Koln                       6
# 12  Fortuna Dusseldorf                      14
# 13       Frankfurt FSV                       8
# 14            Freiburg                       6
# 15      Greuther Furth                      16
# 16             Hamburg                      10
# 17            Hannover                       6
# 18       Hansa Rostock                       6
# 19              Hertha                      20
# 20          Hoffenheim                       2
# 21          Ingolstadt                       6
# 22      Kaiserslautern                      12
# 23           Karlsruhe                       2
# 24          Leverkusen                      14
# 25          M'gladbach                       4
# 26               Mainz                      18
# 27         Munich 1860                      12
# 28            Nurnberg                       4
# 29           Paderborn                       6
# 30          Schalke 04                       8
# 31            St Pauli                      12
# 32           Stuttgart                      20
# 33        Union Berlin                      12
# 34       Werder Bremen                      10
# 35           Wolfsburg                       2

# %%
home_team_draw_goals = cur.execute("""SELECT HomeTeam AS Team, SUM(FTHG) AS TotalHomeTeamDrawGoals
                             From Matches
                             JOIN Teams_in_Matches
                             ON Matches.Match_ID = Teams_in_Matches.Match_ID
                             WHERE Matches.Season = 2011 AND (Matches.Div = "D1" OR Matches.Div = "D2") AND FTR = "D"
                             GROUP BY Team
                             ORDER BY Team""")

# %%
home_team_draw_goals_df = pd.DataFrame(cur.fetchall())
home_team_draw_goals_df.columns = [i[0] for i in cur.description]

# %%
home_team_draw_goals_df
# Out:
#                   Team  TotalHomeTeamDrawGoals
# 0               Aachen                      10
# 1             Augsburg                      12
# 2        Bayern Munich                       0
# 3               Bochum                       6
# 4         Braunschweig                       6
# 5              Cottbus                      18
# 6             Dortmund                      10
# 7              Dresden                      12
# 8             Duisburg                       2
# 9        Ein Frankfurt                       6
# 10      Erzgebirge Aue                      10
# 11             FC Koln                       8
# 12  Fortuna Dusseldorf                       8
# 13       Frankfurt FSV                      22
# 14            Freiburg                      14
# 15      Greuther Furth                       2
# 16             Hamburg                      14
# 17            Hannover                      14
# 18       Hansa Rostock                      12
# 19              Hertha                      10
# 20          Hoffenheim                      16
# 21          Ingolstadt                      20
# 22      Kaiserslautern                       6
# 23           Karlsruhe                       8
# 24          Leverkusen                      14
# 25          M'gladbach                      10
# 26               Mainz                       2
# 27         Munich 1860                       4
# 28            Nurnberg                      14
# 29           Paderborn                      12
# 30          Schalke 04                       2
# 31            St Pauli                       4
# 32           Stuttgart                       6
# 33        Union Berlin                       2
# 34       Werder Bremen                      10
# 35           Wolfsburg                       4

# %%
total_goals_df = away_team_goals_df.merge(home_team_goals_df, on="Team").merge(away_team_draw_goals_df, on="Team").merge(home_team_draw_goals_df, on="Team")

# %%
total_goals_df.insert(5,"TotalGoals", total_goals_df["TotalAwayGoals"]+total_goals_df["TotalHomeGoals"]+total_goals_df["TotalAwayTeamDrawGoals"]+total_goals_df["TotalHomeTeamDrawGoals"])

# %%
total_goals_df.sort_values(by="TotalGoals", ascending=False)
# Out:
#                   Team  TotalAwayGoals  TotalHomeGoals  \
# 6             Dortmund              66              76
# 9        Ein Frankfurt              60              70
# 2        Bayern Munich              46              98
# 30          Schalke 04              40              88
# 15      Greuther Furth              34              84
# 12  Fortuna Dusseldorf              38              58
# 32           Stuttgart              26              62
# 31            St Pauli              28              62
# 27         Munich 1860              32              56
# 29           Paderborn              38              42
# 24          Leverkusen              30              38
# 25          M'gladbach              34              46
# 33        Union Berlin              20              58
# 7              Dresden              18              42
# 34       Werder Bremen              16              46
# 17            Hannover               6              48
# 26               Mainz              10              42
# 13       Frankfurt FSV              28              14
# 35           Wolfsburg              20              44
# 4         Braunschweig              18              34
# 20          Hoffenheim              28              18
# 14            Freiburg              18              26
# 8             Duisburg               8              40
# 28            Nurnberg              24              22
# 3               Bochum              20              36
# 19              Hertha              16              16
# 21          Ingolstadt               6              30
# 1             Augsburg               6              22
# 11             FC Koln              18              24
# 16             Hamburg              16              10
# 23           Karlsruhe               4              34
# 10      Erzgebirge Aue              12              20
# 5              Cottbus              12              16
# 0               Aachen               8              16
# 18       Hansa Rostock               4              16
# 22      Kaiserslautern               8               8
#
#     TotalAwayTeamDrawGoals  TotalHomeTeamDrawGoals  TotalGoals
# 6                        4                      10         156
# 9                       10                       6         146
# 2                        2                       0         146
# 30                       8                       2         138
# 15                      16                       2         136
# 12                      14                       8         118
# 32                      20                       6         114
# 31                      12                       4         106
# 27                      12                       4         104
# 29                       6                      12          98
# 24                      14                      14          96
# 25                       4                      10          94
# 33                      12                       2          92
# 7                       12                      12          84
# 34                      10                      10          82
# 17                       6                      14          74
# 26                      18                       2          72
# 13                       8                      22          72
# 35                       2                       4          70
# 4                       12                       6          70
# 20                       2                      16          64
# 14                       6                      14          64
# 8                       14                       2          64
# 28                       4                      14          64
# 3                        2                       6          64
# 19                      20                      10          62
# 21                       6                      20          62
# 1                       18                      12          58
# 11                       6                       8          56
# 16                      10                      14          50
# 23                       2                       8          48
# 10                       6                      10          48
# 5                        2                      18          48
# 0                       12                      10          46
# 18                       6                      12          38
# 22                      12                       6          34
