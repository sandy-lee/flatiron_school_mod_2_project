# %%
import pandas as pd
import sqlite3 
conn = sqlite3.connect('database.sqlite')
cur = conn.cursor()

# %%
all_german_2011_season = cur.execute("""SELECT Matches.Match_ID, HomeTeam, AwayTeam, FTHG, FTAG, FTR, Date
                       From Matches
                       JOIN Teams_in_Matches
                       ON Matches.Match_ID = Teams_in_Matches.Match_ID
                       WHERE Matches.Season = 2011 AND (Matches.Div = "D1" OR Matches.Div = "D2")
                       """)

# %%
all_german_2011_season_df = pd.DataFrame(cur.fetchall())
all_german_2011_season_df.columns = [i[0] for i in cur.description]

# %%
all_german_2011_season_df
# Out:
#       Match_ID        HomeTeam            AwayTeam  FTHG  FTAG FTR        Date
# 0         1092        Nurnberg       Bayern Munich     0     1   A  2012-03-31
# 1         1092        Nurnberg       Bayern Munich     0     1   A  2012-03-31
# 2         1093       Stuttgart       Bayern Munich     1     2   A  2011-12-11
# 3         1093       Stuttgart       Bayern Munich     1     2   A  2011-12-11
# 4         1094       Wolfsburg       Bayern Munich     0     1   A  2011-08-13
# ...        ...             ...                 ...   ...   ...  ..         ...
# 1219      1701   Ein Frankfurt  Fortuna Dusseldorf     1     1   D  2011-08-15
# 1220      1702          Aachen  Fortuna Dusseldorf     0     0   D  2011-08-27
# 1221      1702          Aachen  Fortuna Dusseldorf     0     0   D  2011-08-27
# 1222      1703  Erzgebirge Aue  Fortuna Dusseldorf     2     4   A  2011-09-16
# 1223      1703  Erzgebirge Aue  Fortuna Dusseldorf     2     4   A  2011-09-16
#
# [1224 rows x 7 columns]

# %%
teams = ['Aachen', 
         'Augsburg',
         'Bayern Munich', 
         'Bochum', 
         'Braunschweig', 
         'Cottbus',
         'Dortmund',
         'Dresden',
         'Duisburg',
         'Ein Frankfurt',
         'Erzgebirge Aue',
         'FC Koln',
         'Fortuna Dusseldorf',
         'Frankfurt FSV',
         'Freiburg',
         'Greuther Furth',
         'Hamburg',
         'Hannover',
         'Hansa Rostock',
         'Hertha',
         'Hoffenheim',
         'Ingolstadt',
         'Kaiserslautern',
         'Karlsruhe',
         'Leverkusen',
         'M\'gladbach',
         'Mainz',
         'Munich 1860',
         'Nurnberg',
         'Paderborn',
         'Schalke 04',
         'St Pauli',
         'Stuttgart',
         'Union Berlin',
         'Werder Bremen',
         'Wolfsburg']

# %%
win_lose_count_dataframe_shape = {'Team': teams, 
                                  'Wins': [0]*36, 
                                  'Loses': [0]*36,
                                  'Draws': [0]*36}

# %%
win_lose_count_df = pd.DataFrame(data=win_lose_count_dataframe_shape)

# %%
win_lose_count_df.set_index(keys="Team", inplace=True)

# %%
win_lose_count_df['Draws'] = win_lose_count_df.astype({"Draws":"float"})

# %%
win_lose_count_df
# Out:
#                     Wins  Loses  Draws
# Team
# Aachen                 0      0    0.0
# Augsburg               0      0    0.0
# Bayern Munich          0      0    0.0
# Bochum                 0      0    0.0
# Braunschweig           0      0    0.0
# Cottbus                0      0    0.0
# Dortmund               0      0    0.0
# Dresden                0      0    0.0
# Duisburg               0      0    0.0
# Ein Frankfurt          0      0    0.0
# Erzgebirge Aue         0      0    0.0
# FC Koln                0      0    0.0
# Fortuna Dusseldorf     0      0    0.0
# Frankfurt FSV          0      0    0.0
# Freiburg               0      0    0.0
# Greuther Furth         0      0    0.0
# Hamburg                0      0    0.0
# Hannover               0      0    0.0
# Hansa Rostock          0      0    0.0
# Hertha                 0      0    0.0
# Hoffenheim             0      0    0.0
# Ingolstadt             0      0    0.0
# Kaiserslautern         0      0    0.0
# ...

# %%
for i, row in all_german_2011_season_df.iterrows():
    if row['FTR'] == 'A':
        win_lose_count_df.loc[row["AwayTeam"]]["Wins"] +=1
    if row['FTR'] == 'H':
        win_lose_count_df.loc[row["HomeTeam"]]["Wins"] +=1
    if row['FTR'] == 'D':
        win_lose_count_df.loc[row["HomeTeam"]]["Draws"] += 0.5
# Out:
# /opt/anaconda3/envs/PandasCourse/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/PandasCourse/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/envs/PandasCourse/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Out:
# Match_ID             1092
# HomeTeam         Nurnberg
# AwayTeam    Bayern Munich
# FTHG                    0
# FTAG                    1
# FTR                     A
# Date           2012-03-31
# Name: 0, dtype: object
# Match_ID             1092
# HomeTeam         Nurnberg
# AwayTeam    Bayern Munich
# FTHG                    0
# FTAG                    1
# FTR                     A
# Date           2012-03-31
# Name: 1, dtype: object
# Match_ID             1093
# HomeTeam        Stuttgart
# AwayTeam    Bayern Munich
# FTHG                    1
# FTAG                    2
# FTR                     A
# Date           2011-12-11
# Name: 2, dtype: object
# Match_ID             1093
# HomeTeam        Stuttgart
# AwayTeam    Bayern Munich
# FTHG                    1
# FTAG                    2
# FTR                     A
# Date           2011-12-11
# Name: 3, dtype: object
# Match_ID             1094
# HomeTeam        Wolfsburg
# AwayTeam    Bayern Munich
# FTHG                    0
# ...
